# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("House_Data.csv")

# %%
x = df[['Area', 'Floors', 'Age']]
y = df['Price']

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
df
# Out:
#     Area  Floors  Age    Price
# 0   1660       2   16  3488251
# 1   2094       3    4  4751481
# 2   1930       1   16  3912566
# 3   1895       2   23  3885945
# 4   2438       2   16  5106852
# ..   ...     ...  ...      ...
# 95  1191       2   18  2505373
# 96  2498       2   15  5289233
# 97  1218       1   15  2483532
# 98  3136       4    2  7044658
# 99  1178       1   19  2389633
#
# [100 rows x 4 columns]

# %%
y_pred = model.predict(x)

# %%
plt.scatter(y, y_pred, color='blue', alpha=0.8)
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red')
plt.xlabel("Actual Price (PKR)")
plt.ylabel("Predicted Price (PKR)")
plt.title("Actual vs Predicted House Prices")
plt.grid(True)
plt.show()

# %%
df
# Out:
#     Area  Floors  Age    Price
# 0   1660       2   16  3488251
# 1   2094       3    4  4751481
# 2   1930       1   16  3912566
# 3   1895       2   23  3885945
# 4   2438       2   16  5106852
# ..   ...     ...  ...      ...
# 95  1191       2   18  2505373
# 96  2498       2   15  5289233
# 97  1218       1   15  2483532
# 98  3136       4    2  7044658
# 99  1178       1   19  2389633
#
# [100 rows x 4 columns]

# %%
input_data = pd.DataFrame([[1800, 2, 3]], columns=["Area", "Floors", "Age"])

predicted_price = model.predict(input_data)
print("Predicted Price:", predicted_price[0])
# Out:
# Predicted Price: 3979545.578377268

# %%
model.coef_
# Out:
# array([  1975.51260511, 219250.19049918, -10641.84326067])
